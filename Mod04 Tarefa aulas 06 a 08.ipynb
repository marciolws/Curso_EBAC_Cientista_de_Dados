# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
#Para iniciar, pegaremos o PVL referente ao estado do Rio de Janeiro
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

# %%
#Aqui usaremos o requests para inserir os dados em uma variavel.
r = requests.get(url)

# %%
#Precisamos ter como resultado, 200. Assim podemos confirmar que o link esta ok
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 7080, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000492/2012-28', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 300000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '03/09/2012'}, {'id_pleito': 8556, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000797/2010-78', 'data_protocolo': '2011-06-30T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'M
# ...

# %%
#Aqui, iremos inserir os dados num dataframe e depois uso o head e info para verificar os dados.

df = pd.DataFrame(data_json['items'])

# %%
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       7080           Estado  Rio de Janeiro        33  RJ    None
# 1       8556           Estado  Rio de Janeiro        33  RJ    None
# 2       9750           Estado  Rio de Janeiro        33  RJ    None
# 3      10002           Estado  Rio de Janeiro        33  RJ    None
# 4      10673           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000492/2012-28
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
# 2                                           Deferido  17944.001046/2006-92
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.001097/2009-67
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001256/2010-67
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
# ...

# %%
# Usamos o value_counts para verificar quais são os dados do status e sua frequência

df['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: count, dtype: int64

# %%
#Para vizualizar os anos dos status, criei uma nova variável chamada data_status.

data_status = df['data_status']

data_status
# Out:
# 0     03/09/2012
# 1     04/07/2011
# 2     13/07/2006
# 3     28/09/2009
# 4     04/07/2011
# 5     04/07/2011
# 6     04/10/2012
# 7     27/06/2002
# 8     25/11/2009
# 9     26/02/2016
# 10    10/07/2012
# 11    14/05/2012
# 12    28/08/2012
# 13    09/12/2009
# 14    05/02/2014
# 15    01/04/2013
# 16    28/03/2013
# 17    18/06/2009
# 18    06/03/2008
# 19    14/09/2012
# 20    02/07/2012
# 21    20/04/2010
# 22    27/06/2002
# 23    01/09/2014
# 24    01/09/2014
# 25    20/11/2012
# 26    29/05/2012
# 27    21/11/2013
# 28    06/05/2013
# 29    29/07/2013
# 30    06/05/2013
# 31    27/12/2013
# 32    27/06/2002
# 33    10/07/2012
# 34    07/06/2011
# 35    25/10/2016
# 36    04/11/2009
# 37    11/03/2016
# 38    18/04/2008
# 39    07/07/2009
# 40    22/05/2009
# 41    27/12/2011
# 42    01/03/2006
# 43    16/05/2016
# 44    06/08/2009
# 45    24/07/2009
# 46    04/07/2014
# 47    19/08/2010
# 48    27/06/2002
# 49    04/10/2012
# 50    04/07/2011
# 51    06/07/2010
# ...

# %%
# Após colocar os dados de ano dentro de uma variável, transformei os dados em string para pegar apenas o ano.

lista_anos = []
for data in data_status:
    data_valor = str(data)
    lista_anos.append(data_valor[6:])

# %%
#Transformando a lista em uma Series e fazendo a contagem de frequencia dos anos.

pd.Series(lista_anos).value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2002     4
# 2016     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#Teremos a função que pega a UF e o tipo de interesse como parâmetros.
#Dentro deles há uma condicional que diz se foi selecionado municipio ou estado.
#Realizando alguns testes verifiquei que a única coisa que mudava nas urls era a UF e se era municipio.
#Aloquei as partes da url em variáveis e depois fiz uma soma de string que junta tudo.
#Por fim, repeti o procedimento realizado anteriormente para pegar os dados.

def consulta(UF: str, interessado: str):

    if interessado == 'municipio':
        tipo_interessado = 'Munic%C3%ADpio'
    else:
        tipo_interessado = 'Estado'

    url_1 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf='
    url_2 = '&tipo_interessado='

    url_final = url_1 + UF + url_2 + tipo_interessado

    r = requests.get(url_final)

    data_jason = r.json()

    df_1 = pd.DataFrame(data_jason['items'])

    return df_1

# %%
#Usada a função para pegar os dados do estado da Bahia.

df_2 = consulta(UF='MG', interessado='estado')

# %%
df_2['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Em retificação pelo interessado                           1
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: count, dtype: int64

# %%
#Usando novamente a função criando dados para Bahia, só que agora para municipio

df_3 = consulta(UF='BA', interessado='municipio')

# %%
df_3.head()
# Out:
#    id_pleito tipo_interessado       interessado  cod_ibge  uf  \
# 0      11165        Município           Igaporã   2913408  BA
# 1      10747        Município  Lauro de Freitas   2919207  BA
# 2      64692        Município          Olindina   2923100  BA
# 3      64694        Município          Olindina   2923100  BA
# 4      68812        Município             Mairi   2920106  BA
#
#                 num_pvl             status          num_processo  \
# 0                  None           Deferido  17944.001375/2008-03
# 1                  None           Deferido  17944.001273/2011-85
# 2  PVL02.001757/2023-03  Deferido (PVL-IF)                  None
# 3  PVL02.001759/2023-94  Deferido (PVL-IF)                  None
# 4  PVL02.001117/2024-76  Deferido (PVL-IF)                  None
#
#          data_protocolo                tipo_operacao  \
# 0  2008-05-23T03:00:00Z  Operação contratual interna
# 1  2012-01-20T02:00:00Z  Operação contratual interna
# ...

# %%
#Para descobrir qual estado possui mais solicitações, utilizei novamente o value_counts

df_3['interessado'].value_counts()
# Out:
# interessado
# Camaçari                  20
# Salvador                  19
# Luís Eduardo Magalhães    19
# Amargosa                  16
# Vitória da Conquista      16
#                           ..
# Vera Cruz                  1
# Taperoá                    1
# Nova Ibiá                  1
# Palmeiras                  1
# Santa Brígida              1
# Name: count, Length: 303, dtype: int64

# %%
#Código para pegar os dados da BA e área de interesse estado.

df_4 = consulta(UF= 'BA', interessado='estado')

# %%
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       7080           Estado  Rio de Janeiro        33  RJ    None
# 1       8556           Estado  Rio de Janeiro        33  RJ    None
# 2       9750           Estado  Rio de Janeiro        33  RJ    None
# 3      10002           Estado  Rio de Janeiro        33  RJ    None
# 4      10673           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000492/2012-28
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
# 2                                           Deferido  17944.001046/2006-92
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.001097/2009-67
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001256/2010-67
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
#Para salvar os dados em csv, usei o to_csv e inseti a extensão do arquivo como csv

df_4.to_csv('dataframe_BA_Estado.csv')
